# %%
import csv
import requests
import json
import re
import urllib.request
import os
import re
from bs4 import BeautifulSoup
import pandas as pd
from IPython.display import clear_output
import matplotlib.pyplot as plt
from threading import Thread
from nltk.corpus import stopwords
import ast
import warnings
warnings.filterwarnings('ignore')

# %%
type = "decision"
keywords = "drug trafficking"
keywords = keywords.replace(' ', '%20')
base_url = "https://www.canlii.org"
search_url = "/en/search/ajaxSearch.do?type=decision&sort=decisionDateDesc&text="
page_start = 1
page_max = 9999999999999

# %% [markdown]
# https://www.canlii.org/en/search/ajaxSearch.do?type=decision&sort=decisionDateDesc&text=drug%20trafficking&page=1

# %% [markdown]
# https://www.canlii.org/en/search/ajaxSearch.do?type=decision&startDate=1800-01-01&endDate=2021-12-31&sort=decisionDateDesc&text=drug%20trafficking&page=1

# %%
start_date = '1800-01-01'
end_date = '2021-12-31'

first_url_chunk = '/en/search/ajaxSearch.do?type=decision&'
date_url_chunk = 'startDate=' + start_date + '&endDate=' + end_date
last_url_chunk = '&sort=decisionDateDesc&text=' + keywords + '&page=' + str(page)

# %%
'https://www.canlii.org/en/search/ajaxSearch.do?type=decision&startDate=1800-01-01&endDate=2021-12-31&sort=decisionDateDesc&text=drug%20trafficking&page=1'

# %%
def get_config_for_page(page):
    try:
        query_url = base_url + search_url + keywords + '&page=' + str(page)
        response = requests.get(query_url)
        responseJSON = json.loads(response.text)
        response = responseJSON
        return response
    except urllib.error.HTTPError as err:
        print(err)   
        
def get_config_for_page_with_date(page, date):
    start_date = '1800-01-01'
    end_date = date
    first_url_chunk = '/en/search/ajaxSearch.do?type=decision&'
    date_url_chunk = 'startDate=' + start_date + '&endDate=' + end_date
    last_url_chunk = '&sort=decisionDateDesc&text=' + keywords + '&page=' + str(page)
    try:
        query_url = base_url + first_url_chunk + date_url_chunk + last_url_chunk
        response = requests.get(query_url)
        responseJSON = json.loads(response.text)
        response = responseJSON
        return response
    except urllib.error.HTTPError as err:
        print(err)

# %%
def create_case_file_from_config(case):    
    path = case['path']
    date = case['judgmentDate']
    title = case['title']
    concatId = case['concatId']
    topics = case['topics']
    row = {'id': concatId, 'date': date, 'path': path, 'title': title, 'topics': topics}
    
    return row

# %%
# %%time
complete_config = []

previous_config = ''
query_more = True
more_than_fifty = False
page = 1
total_pages = 1
date_to_search_before = ''

case_df = pd.DataFrame(columns = ['id', 'date', 'path', 'title', 'topics'])

while query_more:
        
    if not more_than_fifty:
        print(f"Searching page {page} with no date specified")
        config = get_config_for_page(page)
    else:
        print(f"Seaching page {page} before date {date_to_search_before}")
        config = get_config_for_page_with_date(page, date_to_search_before)
    
    
    
    
    if config != previous_config:
        for case in config['results']:
            row = create_case_file_from_config(case)
            case_df = case_df.append(row, ignore_index=True)
        previous_config = config
        fifty_counter +=1
    else:
        print('is same')
        query_more = False
        
    print(f"Case df has {len(case_df)} cases, total pages: {total_pages}")
    
    page += 1
    total_pages += 1
    if page == 20:
        date_to_search_before = case_df[-1:]['date'].iloc[0]
        more_than_fifty = True
        page = 1    
        
print(f"Handled {total_pages} pages.")

case_df
# Out:
# Searching page 1 with no date specified
# Case df has 25 cases, total pages: 1
# Searching page 2 with no date specified
# Case df has 50 cases, total pages: 2
# Searching page 3 with no date specified
# Case df has 75 cases, total pages: 3
# Searching page 4 with no date specified
# Case df has 100 cases, total pages: 4
# Searching page 5 with no date specified
# Case df has 125 cases, total pages: 5
# Searching page 6 with no date specified
# Case df has 150 cases, total pages: 6
# Searching page 7 with no date specified
# Case df has 175 cases, total pages: 7
# Searching page 8 with no date specified
# Case df has 200 cases, total pages: 8
# Searching page 9 with no date specified
# Case df has 225 cases, total pages: 9
# Searching page 10 with no date specified
# Case df has 250 cases, total pages: 10
# Searching page 11 with no date specified
# Case df has 275 cases, total pages: 11
# Searching page 12 with no date specified
# Case df has 300 cases, total pages: 12
# Searching page 13 with no date specified
# Case df has 325 cases, total pages: 13
# Searching page 14 with no date specified
# Case df has 350 cases, total pages: 14
# Searching page 15 with no date specified
# Case df has 375 cases, total pages: 15
# Searching page 16 with no date specified
# Case df has 400 cases, total pages: 16
# Searching page 17 with no date specified
# Case df has 425 cases, total pages: 17
# Searching page 18 with no date specified
# Case df has 450 cases, total pages: 18
# Searching page 19 with no date specified
# Case df has 475 cases, total pages: 19
# Seaching page 1 before date 2021-10-15
# Case df has 500 cases, total pages: 20
# Seaching page 2 before date 2021-10-15
# Case df has 525 cases, total pages: 21
# Seaching page 3 before date 2021-10-15
# Case df has 550 cases, total pages: 22
# Seaching page 4 before date 2021-10-15
# Case df has 575 cases, total pages: 23
# Seaching page 5 before date 2021-10-15
# Case df has 600 cases, total pages: 24
# Seaching page 6 before date 2021-10-15
# Case df has 625 cases, total pages: 25
# Seaching page 7 before date 2021-10-15
# Case df has 650 cases, total pages: 26
# Seaching page 8 before date 2021-10-15
# Case df has 675 cases, total pages: 27
# Seaching page 9 before date 2021-10-15
# Case df has 700 cases, total pages: 28
# Seaching page 10 before date 2021-10-15
# Case df has 725 cases, total pages: 29
# Seaching page 11 before date 2021-10-15
# Case df has 750 cases, total pages: 30
# Seaching page 12 before date 2021-10-15
# Case df has 775 cases, total pages: 31
# Seaching page 13 before date 2021-10-15
# Case df has 800 cases, total pages: 32
# Seaching page 14 before date 2021-10-15
# Case df has 825 cases, total pages: 33
# Seaching page 15 before date 2021-10-15
# Case df has 850 cases, total pages: 34
# Seaching page 16 before date 2021-10-15
# Case df has 875 cases, total pages: 35
# Seaching page 17 before date 2021-10-15
# Case df has 900 cases, total pages: 36
# Seaching page 18 before date 2021-10-15
# Case df has 925 cases, total pages: 37
# Seaching page 19 before date 2021-10-15
# Case df has 950 cases, total pages: 38
# Seaching page 1 before date 2021-04-09
# Case df has 975 cases, total pages: 39
# Seaching page 2 before date 2021-04-09
# Case df has 1000 cases, total pages: 40
# Seaching page 3 before date 2021-04-09
# Case df has 1025 cases, total pages: 41
# Seaching page 4 before date 2021-04-09
# Case df has 1050 cases, total pages: 42
# Seaching page 5 before date 2021-04-09
# Case df has 1075 cases, total pages: 43
# Seaching page 6 before date 2021-04-09
# Case df has 1100 cases, total pages: 44
# Seaching page 7 before date 2021-04-09
# Case df has 1125 cases, total pages: 45
# Seaching page 8 before date 2021-04-09
# Case df has 1150 cases, total pages: 46
# Seaching page 9 before date 2021-04-09
# Case df has 1175 cases, total pages: 47
# Seaching page 10 before date 2021-04-09
# Case df has 1200 cases, total pages: 48
# Seaching page 11 before date 2021-04-09
# Case df has 1225 cases, total pages: 49
# Seaching page 12 before date 2021-04-09
# Case df has 1250 cases, total pages: 50
# Seaching page 13 before date 2021-04-09
# Case df has 1275 cases, total pages: 51
# Seaching page 14 before date 2021-04-09
# Case df has 1300 cases, total pages: 52
# Seaching page 15 before date 2021-04-09
# Case df has 1325 cases, total pages: 53
# Seaching page 16 before date 2021-04-09
# Case df has 1350 cases, total pages: 54
# Seaching page 17 before date 2021-04-09
# Case df has 1375 cases, total pages: 55
# Seaching page 18 before date 2021-04-09
# Case df has 1400 cases, total pages: 56
# Seaching page 19 before date 2021-04-09
# Case df has 1425 cases, total pages: 57
# Seaching page 1 before date 2020-11-16
# Case df has 1450 cases, total pages: 58
# Seaching page 2 before date 2020-11-16
# Case df has 1475 cases, total pages: 59
# Seaching page 3 before date 2020-11-16
# Case df has 1500 cases, total pages: 60
# Seaching page 4 before date 2020-11-16
# Case df has 1525 cases, total pages: 61
# Seaching page 5 before date 2020-11-16
# Case df has 1550 cases, total pages: 62
# Seaching page 6 before date 2020-11-16
# Case df has 1575 cases, total pages: 63
# Seaching page 7 before date 2020-11-16
# Case df has 1600 cases, total pages: 64
# Seaching page 8 before date 2020-11-16
# Case df has 1625 cases, total pages: 65
# Seaching page 9 before date 2020-11-16
# Case df has 1650 cases, total pages: 66
# Seaching page 10 before date 2020-11-16
# Case df has 1675 cases, total pages: 67
# Seaching page 11 before date 2020-11-16
# Case df has 1700 cases, total pages: 68
# Seaching page 12 before date 2020-11-16
# Case df has 1725 cases, total pages: 69
# Seaching page 13 before date 2020-11-16
# Case df has 1750 cases, total pages: 70
# Seaching page 14 before date 2020-11-16
# Case df has 1775 cases, total pages: 71
# Seaching page 15 before date 2020-11-16
# Case df has 1800 cases, total pages: 72
# Seaching page 16 before date 2020-11-16
# Case df has 1825 cases, total pages: 73
# Seaching page 17 before date 2020-11-16
# Case df has 1850 cases, total pages: 74
# Seaching page 18 before date 2020-11-16
# Case df has 1875 cases, total pages: 75
# Seaching page 19 before date 2020-11-16
# Case df has 1900 cases, total pages: 76
# Seaching page 1 before date 2020-05-06
# Case df has 1925 cases, total pages: 77
# Seaching page 2 before date 2020-05-06
# Case df has 1950 cases, total pages: 78
# Seaching page 3 before date 2020-05-06
# Case df has 1975 cases, total pages: 79
# Seaching page 4 before date 2020-05-06
# Case df has 2000 cases, total pages: 80
# Seaching page 5 before date 2020-05-06
# Case df has 2025 cases, total pages: 81
# Seaching page 6 before date 2020-05-06
# Case df has 2050 cases, total pages: 82
# Seaching page 7 before date 2020-05-06
# Case df has 2075 cases, total pages: 83
# Seaching page 8 before date 2020-05-06
# Case df has 2100 cases, total pages: 84
# Seaching page 9 before date 2020-05-06
# Case df has 2125 cases, total pages: 85
# Seaching page 10 before date 2020-05-06
# Case df has 2150 cases, total pages: 86
# Seaching page 11 before date 2020-05-06
# Case df has 2175 cases, total pages: 87
# Seaching page 12 before date 2020-05-06
# Case df has 2200 cases, total pages: 88
# Seaching page 13 before date 2020-05-06
# Case df has 2225 cases, total pages: 89
# Seaching page 14 before date 2020-05-06
# Case df has 2250 cases, total pages: 90
# Seaching page 15 before date 2020-05-06
# Case df has 2275 cases, total pages: 91
# Seaching page 16 before date 2020-05-06
# Case df has 2300 cases, total pages: 92
# Seaching page 17 before date 2020-05-06
# Case df has 2325 cases, total pages: 93
# Seaching page 18 before date 2020-05-06
# Case df has 2350 cases, total pages: 94
# Seaching page 19 before date 2020-05-06
# Case df has 2375 cases, total pages: 95
# Seaching page 1 before date 2019-11-19
# Case df has 2400 cases, total pages: 96
# Seaching page 2 before date 2019-11-19
# Case df has 2425 cases, total pages: 97
# Seaching page 3 before date 2019-11-19
# Case df has 2450 cases, total pages: 98
# Seaching page 4 before date 2019-11-19
# Case df has 2475 cases, total pages: 99
# Seaching page 5 before date 2019-11-19
# Case df has 2500 cases, total pages: 100
# Seaching page 6 before date 2019-11-19
# Case df has 2525 cases, total pages: 101
# Seaching page 7 before date 2019-11-19
# Case df has 2550 cases, total pages: 102
# Seaching page 8 before date 2019-11-19
# Case df has 2575 cases, total pages: 103
# Seaching page 9 before date 2019-11-19
# Case df has 2600 cases, total pages: 104
# Seaching page 10 before date 2019-11-19
# Case df has 2625 cases, total pages: 105
# Seaching page 11 before date 2019-11-19
# Case df has 2650 cases, total pages: 106
# Seaching page 12 before date 2019-11-19
# Case df has 2675 cases, total pages: 107
# Seaching page 13 before date 2019-11-19
# Case df has 2700 cases, total pages: 108
# Seaching page 14 before date 2019-11-19
# Case df has 2725 cases, total pages: 109
# Seaching page 15 before date 2019-11-19
# Case df has 2750 cases, total pages: 110
# Seaching page 16 before date 2019-11-19
# Case df has 2775 cases, total pages: 111
# Seaching page 17 before date 2019-11-19
# Case df has 2800 cases, total pages: 112
# Seaching page 18 before date 2019-11-19
# Case df has 2825 cases, total pages: 113
# Seaching page 19 before date 2019-11-19
# Case df has 2850 cases, total pages: 114
# Seaching page 1 before date 2019-06-14
# Case df has 2875 cases, total pages: 115
# Seaching page 2 before date 2019-06-14
# Case df has 2900 cases, total pages: 116
# Seaching page 3 before date 2019-06-14
# Case df has 2925 cases, total pages: 117
# Seaching page 4 before date 2019-06-14
# Case df has 2950 cases, total pages: 118
# Seaching page 5 before date 2019-06-14
# Case df has 2975 cases, total pages: 119
# Seaching page 6 before date 2019-06-14
# Case df has 3000 cases, total pages: 120
# Seaching page 7 before date 2019-06-14
# Case df has 3025 cases, total pages: 121
# Seaching page 8 before date 2019-06-14
# Case df has 3050 cases, total pages: 122
# Seaching page 9 before date 2019-06-14
# Case df has 3075 cases, total pages: 123
# Seaching page 10 before date 2019-06-14
# Case df has 3100 cases, total pages: 124
# Seaching page 11 before date 2019-06-14
# Case df has 3125 cases, total pages: 125
# Seaching page 12 before date 2019-06-14
# Case df has 3150 cases, total pages: 126
# Seaching page 13 before date 2019-06-14
# Case df has 3175 cases, total pages: 127
# Seaching page 14 before date 2019-06-14
# Case df has 3200 cases, total pages: 128
# Seaching page 15 before date 2019-06-14
# Case df has 3225 cases, total pages: 129
# Seaching page 16 before date 2019-06-14
# Case df has 3250 cases, total pages: 130
# Seaching page 17 before date 2019-06-14
# Case df has 3275 cases, total pages: 131
# Seaching page 18 before date 2019-06-14
# Case df has 3300 cases, total pages: 132
# Seaching page 19 before date 2019-06-14
# Case df has 3325 cases, total pages: 133
# Seaching page 1 before date 2019-01-29
# Case df has 3350 cases, total pages: 134
# Seaching page 2 before date 2019-01-29
# Case df has 3375 cases, total pages: 135
# Seaching page 3 before date 2019-01-29
# Case df has 3400 cases, total pages: 136
# Seaching page 4 before date 2019-01-29
# Case df has 3425 cases, total pages: 137
# Seaching page 5 before date 2019-01-29
# Case df has 3450 cases, total pages: 138
# Seaching page 6 before date 2019-01-29
# Case df has 3475 cases, total pages: 139
# Seaching page 7 before date 2019-01-29
# Case df has 3500 cases, total pages: 140
# Seaching page 8 before date 2019-01-29
# Case df has 3525 cases, total pages: 141
# Seaching page 9 before date 2019-01-29
# Case df has 3550 cases, total pages: 142
# Seaching page 10 before date 2019-01-29
# Case df has 3575 cases, total pages: 143
# Seaching page 11 before date 2019-01-29
# Case df has 3600 cases, total pages: 144
# Seaching page 12 before date 2019-01-29
# Case df has 3625 cases, total pages: 145
# Seaching page 13 before date 2019-01-29
# Case df has 3650 cases, total pages: 146
# Seaching page 14 before date 2019-01-29
# Case df has 3675 cases, total pages: 147
# Seaching page 15 before date 2019-01-29
# Case df has 3700 cases, total pages: 148
# Seaching page 16 before date 2019-01-29
# Case df has 3725 cases, total pages: 149
# Seaching page 17 before date 2019-01-29
# Case df has 3750 cases, total pages: 150
# Seaching page 18 before date 2019-01-29
# Case df has 3775 cases, total pages: 151
# Seaching page 19 before date 2019-01-29
# Case df has 3800 cases, total pages: 152
# Seaching page 1 before date 2018-09-18
# Case df has 3825 cases, total pages: 153
# Seaching page 2 before date 2018-09-18
# Case df has 3850 cases, total pages: 154
# Seaching page 3 before date 2018-09-18
# Case df has 3875 cases, total pages: 155
# Seaching page 4 before date 2018-09-18
# Case df has 3900 cases, total pages: 156
# Seaching page 5 before date 2018-09-18
# Case df has 3925 cases, total pages: 157
# Seaching page 6 before date 2018-09-18
# Case df has 3950 cases, total pages: 158
# Seaching page 7 before date 2018-09-18

# %%
df.to_csv('out.zip', index=False,

# %%
case_df.to_csv('canadian court cases/cases.csv', index=False)

# %%
case_list = response['results']

# %%
def get_case_text(path):
    text = ''
    try:
        query_url = base_url + path
        response = requests.get(query_url)
        case_text = response.text
        soup = BeautifulSoup(case_text, 'html.parser')
        documentContainer = soup.find('div', {'id': 'documentContainer'})
        documentContent = documentContainer.find('div', {'id': 'documentContent'})
        originalDocument = documentContent.find('div', {'id': 'originalDocument'})
        originalDocument_divs = originalDocument.find_all('div', attrs={'class': re.compile('^WordSection.*')})
        for div in originalDocument_divs:
            text+= div.text
        return text
    except Exception as err:
        print(err)

case_text = get_case_text('/en/ab/abpc/doc/2021/2021abpc264/2021abpc264.html')

# %%
case_df = pd.DataFrame(columns = ['id', 'date', 'path', 'title'])
  
for case in response['results']:
    row = create_case_file(case)
    case_df = case_df.append(row, ignore_index=True)
    
case_df
# Out:
#                   id        date  \
# 0        2021abpc264  2021-10-15
# 1       2021onsc7615  2021-10-14
# 2       2021bcsc2199  2021-10-14
# 3        2021oncj559  2021-10-14
# 4         2021mbpc49  2021-10-14
# 5        2021bcpc250  2021-10-14
# 6         2021ntsc34  2021-10-13
# 7       2021onsc6798  2021-10-13
# 8        2021abqb811  2021-10-13
# 9   2021onltb1013815  2021-10-12
# 10  2021onltb1014220  2021-10-12
# 11       2021fct1047  2021-10-12
# 12       2021fct1062  2021-10-12
# 13      2021onsc7025  2021-10-12
# 14        2021skpc48  2021-10-12
# 15       2021bcca401  2021-10-08
# 16      2021bcsc2090  2021-10-08
# 17       2021abqb803  2021-10-08
# 18       2021bcpc253  2021-10-08
# 19     2021qccq13105  2021-10-08
# 20  2021onltb1014423  2021-10-07
# 21       2021onca695  2021-10-07
# 22      2021onsc6683  2021-10-07
# 23      2021onsc6607  2021-10-07
# 24  2021onltb1014517  2021-10-06
#
#                                                  path  \
# 0   /en/ab/abpc/doc/2021/2021abpc264/2021abpc264.html
# 1   /en/on/onsc/doc/2021/2021onsc7615/2021onsc7615...
# 2   /en/bc/bcsc/doc/2021/2021bcsc2199/2021bcsc2199...
# 3   /en/on/oncj/doc/2021/2021oncj559/2021oncj559.html
# 4     /en/mb/mbpc/doc/2021/2021mbpc49/2021mbpc49.html
# 5   /en/bc/bcpc/doc/2021/2021bcpc250/2021bcpc250.html
# 6   /en/nt/ntsc/doc/2021/2021nwtsc34/2021nwtsc34.html
# 7   /en/on/onsc/doc/2021/2021onsc6798/2021onsc6798...
# 8   /en/ab/abqb/doc/2021/2021abqb811/2021abqb811.html
# 9   /en/on/onltb/doc/2021/2021canlii139717/2021can...
# 10  /en/on/onltb/doc/2021/2021canlii140664/2021can...
# 11     /en/ca/fct/doc/2021/2021fc1047/2021fc1047.html
# 12     /en/ca/fct/doc/2021/2021fc1062/2021fc1062.html
# 13  /en/on/onsc/doc/2021/2021onsc7025/2021onsc7025...
# 14    /en/sk/skpc/doc/2021/2021skpc48/2021skpc48.html
# 15  /en/bc/bcca/doc/2021/2021bcca401/2021bcca401.html
# 16  /en/bc/bcsc/doc/2021/2021bcsc2090/2021bcsc2090...
# 17  /en/ab/abqb/doc/2021/2021abqb803/2021abqb803.html
# 18  /en/bc/bcpc/doc/2021/2021bcpc253/2021bcpc253.html
# 19  /en/qc/qccq/doc/2021/2021qccq13105/2021qccq131...
# 20  /en/on/onltb/doc/2021/2021canlii141490/2021can...
# 21  /en/on/onca/doc/2021/2021onca695/2021onca695.html
# 22  /en/on/onsc/doc/2021/2021onsc6683/2021onsc6683...
# 23  /en/on/onsc/doc/2021/2021onsc6607/2021onsc6607...
# 24  /en/on/onltb/doc/2021/2021canlii141921/2021can...
#
#                                                 title
# 0                                             R v Bay
# 1                                       R. v. Mohamed
# 2                                        R. v Lambert
# 3                                       R. v. Stewart
# 4                                    R. v. Krywonizka
# 5                                    T.L.C. v. K.J.H.
# 6                                            R v Omar
# 7                                       R. v. Moseley
# 8                                          R v Wallis
# 9                         2295477 Ontario Inc. v Chen
# 10                2455644 Ontario Limited v Grigalius
# 11  Canada (Public Safety and Emergency Preparedne...
# 12             Stuckless v. Canada (Attorney General)
# 13                                      R. v. Baldwin
# 14                                          R v Flett
# 15                                     R. v. Laflamme
# 16                  United States of America v Fraser
# 17                                          R v Scher
# 18                                       R. v. Mykell
# 19                                      Martell c. R.
# 20     Absolute Real Estate Management Ltd. v Jackson
# 21                                       R. v. Davies
# 22                                       R. v. O.(R.)
# 23                                R. v. Owusu-Sarpong
# 24              Toronto Community Housing Corp v Bent

# %%
# Out:
# {'concatId': '2021abpc264', 'path': '/en/ab/abpc/doc/2021/2021abpc264/2021abpc264.html', 'title': 'R v Bay', 'reference': '2021 ABPC 264 (CanLII)', 'judgmentDate': '2021-10-15', 'collectionTitle': 'Provincial Court', 'jurisdictionTitle': 'Alberta', 'jurisdictionId': 'ab', 'keywords': 'firearms — locker — garage — gun safe — evidence', 'topics': [], 'firstSyncDate': 'Oct 18, 2021, 7:34:35 PM', 'updateDate': 'Oct 18, 2021, 12:00:00 AM', 'templateName': 'CanliiCaselawIndexedResult.ftl', 'resultNumber': 476, 'snippet': '[…]\xa0\xa0 Additionally, she is charged with two counts simple possession of a controlled substance pursuant to the Controlled <b>Drugs</b> and Substances Act.  \xa0\xa0[…]\xa0\xa0 [48] Counts 1-12 are charges pursuant to section 99(1) of the Criminal Code commonly known as Weapons <b>Trafficking</b>.  \xa0\xa0[…]\xa0\xa0 Possession of those <b>drugs</b> is an offence contrary the Controlled <b>Drugs</b> and Substances Act. These <b>drugs</b> were found in Ms. Bay’s purse and although she provides and explanation during re-examination the explanation refers to a bottle that Mr. Layton’s brother in law found in her massage room.  \xa0\xa0[…]', 'citationCount': '0', 'negativityScore': 0, 'cautionaryScore': 0, 'pagesCount': '19', 'searchUrlHash': 'AAAAAQAQZHJ1ZyB0cmFmZmlja2luZwAAAAAB', 'noteupSearchPath': '/en/#search/origin1=/en/ab/abpc/doc/2021/2021abpc264/2021abpc264.html&amp;nquery1=2021 ABPC 264 (CanLII)&amp;linkedNoteup=', 'score': '62.549473', 'discussionDetails': {'mentionTypesWithCount': {}, 'mentionTypesWithBoost': {'CAUTIONARY': 25.0, 'CH-CAUTIONARY': 25.0, 'CH-INDETERMINATE': 1.0, 'CH-NEGATIVE': 25.0, 'CH-NEUTRAL': 5.0, 'CH-POSITIVE': 10.0, 'MENTION': 2.0, 'NEGATIVE': 25.0, 'NEUTRAL': 5.0, 'POSITIVE': 10.0}}, 'discussionScore': 0.0, 'discussionWeight': 0, 'discussionThreshold': '10,20,50,100,200', 'commentaryDeboost': 0.1, 'hasCriticizingNoteup': False, 'hasNegatingNoteup': False}

# %%
for case in response['results']:
    path = case['path']
    print(path)
    text = get_case_text(path)
    print(len(text))
# Out:
# /en/ab/abpc/doc/2021/2021abpc264/2021abpc264.html
# 36397
# /en/on/onsc/doc/2021/2021onsc7615/2021onsc7615.html
# 44049
# /en/bc/bcsc/doc/2021/2021bcsc2199/2021bcsc2199.html
# 26381
# /en/on/oncj/doc/2021/2021oncj559/2021oncj559.html
# 69750
# /en/mb/mbpc/doc/2021/2021mbpc49/2021mbpc49.html
# 41945
# /en/bc/bcpc/doc/2021/2021bcpc250/2021bcpc250.html
# 232942
# /en/nt/ntsc/doc/2021/2021nwtsc34/2021nwtsc34.html
# 50607
# /en/on/onsc/doc/2021/2021onsc6798/2021onsc6798.html
# 13783
# /en/ab/abqb/doc/2021/2021abqb811/2021abqb811.html
# 60001
# /en/on/onltb/doc/2021/2021canlii139717/2021canlii139717.html
# 11309
# /en/on/onltb/doc/2021/2021canlii140664/2021canlii140664.html
# 8830
# /en/ca/fct/doc/2021/2021fc1047/2021fc1047.html
# 39674
# /en/ca/fct/doc/2021/2021fc1062/2021fc1062.html
# 56727
# /en/on/onsc/doc/2021/2021onsc7025/2021onsc7025.html
# 39140
# /en/sk/skpc/doc/2021/2021skpc48/2021skpc48.html
# 40332
# /en/bc/bcca/doc/2021/2021bcca401/2021bcca401.html
# 18314
# /en/bc/bcsc/doc/2021/2021bcsc2090/2021bcsc2090.html
# 70660
# /en/ab/abqb/doc/2021/2021abqb803/2021abqb803.html
# 83637
# /en/bc/bcpc/doc/2021/2021bcpc253/2021bcpc253.html
# 27592
# /en/qc/qccq/doc/2021/2021qccq13105/2021qccq13105.html
# 291349
# /en/on/onltb/doc/2021/2021canlii141490/2021canlii141490.html
# 7110
# /en/on/onca/doc/2021/2021onca695/2021onca695.html
# 2918
# /en/on/onsc/doc/2021/2021onsc6683/2021onsc6683.html
# 16373
# /en/on/onsc/doc/2021/2021onsc6607/2021onsc6607.html
# 47629
# /en/on/onltb/doc/2021/2021canlii141921/2021canlii141921.html
# 5601

# %%
first['path']
# Out:
# '/en/ab/abqb/doc/2022/2022abqb412/2022abqb412.html'

# %%
text = ''
soup = BeautifulSoup(example_case_text, 'html.parser')
documentContainer = soup.find('div', {'id': 'documentContainer'})
documentContent = documentContainer.find('div', {'id': 'documentContent'})
originalDocument = documentContent.find('div', {'id': 'originalDocument'})
originalDocument_divs = originalDocument.find_all('div', attrs={'class': re.compile('^WordSection.*')})

for div in originalDocument_divs:
    text+= div.text
    print(len(text))
# len(originalDocument_divs)
# print(originalDocument_divs[0].text)
# Out:
# 226
# 30387

# %%
soup = BeautifulSoup(response.text, 'html.parser')
            soup_content = soup.find("div", {"id": 'content'})
            if df.iloc[i]['verdict_type'] == 'uitspraak':
                statement_content = soup_content.find('div', {'class': 'uitspraak'})
            elif df.iloc[i]['verdict_type'] == 'conclusie':
                statement_content = soup_content.find('div', {'class': 'conclusie'})
            
            sections = {}
            for el in statement_content.find_all(attrs={'class': 'section'}):
                section_title = clean_string(el.find('h2').text)
                print(section_title)
                sections[section_title] = el
